# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv("IPLData.csv")

# %%
df
# Out:
#          Player Name       Team Nationality Player_Type  Capped  \
# 0     Shikhar Dhawan     Punjab      Indian      Batter       1
# 1      Shreyas Iyer     Kolkata      Indian      Batter       1
# 2     Faf Du Plessis  Bangalore    Overseas      Batter       1
# 3     Manish Pandey     Lucknow      Indian      Batter       1
# 4    Shimron Hetmyer  Rajasthan    Overseas      Batter       1
# ..               ...        ...         ...         ...     ...
# 230     Ravi Bishnoi    Lucknow      Indian     Bowler        1
# 231  Ruturaj Gaikwad    Chennai      Indian      Batter       1
# 232    Sunil Narine     Kolkata    Overseas  Allrounder       1
# 233  Kieron Pollard      Mumbai    Overseas  Allrounder       1
# 234    Anrich Nortje      Delhi    Overseas     Bowler        1
#
#      Matches_Played    Runs  Average  Strike_Rate  Wickets  Bowling_average  \
# 0             192.0  5783.0    34.63       126.60      4.0            16.50
# ...

# %%
df
# Out:
#          Player Name       Team Nationality Player_Type  Capped  \
# 0     Shikhar Dhawan     Punjab      Indian      Batter       1
# 1      Shreyas Iyer     Kolkata      Indian      Batter       1
# 2     Faf Du Plessis  Bangalore    Overseas      Batter       1
# 3     Manish Pandey     Lucknow      Indian      Batter       1
# 4    Shimron Hetmyer  Rajasthan    Overseas      Batter       1
# ..               ...        ...         ...         ...     ...
# 230     Ravi Bishnoi    Lucknow      Indian     Bowler        1
# 231  Ruturaj Gaikwad    Chennai      Indian      Batter       1
# 232    Sunil Narine     Kolkata    Overseas  Allrounder       1
# 233  Kieron Pollard      Mumbai    Overseas  Allrounder       1
# 234    Anrich Nortje      Delhi    Overseas     Bowler        1
#
#      Matches_Played    Runs  Average  Strike_Rate  Wickets  Bowling_average  \
# 0             192.0  5783.0    34.63       126.60      4.0            16.50
# ...

# %%
df.isna().sum()
# Out:
# Player Name              0
# Team                     0
# Nationality              0
# Player_Type              0
# Capped                   0
# Matches_Played          20
# Runs                    70
# Average                 74
# Strike_Rate             72
# Wickets                 95
# Bowling_average        100
# Economy                 92
# Bowling_Strike_Rate    116
# Catches                208
# Run_outs               208
# Stumps                 208
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 235 entries, 0 to 234
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Player Name          235 non-null    object
#  1   Team                 235 non-null    object
#  2   Nationality          235 non-null    object
#  3   Player_Type          235 non-null    object
#  4   Capped               235 non-null    int64
#  5   Matches_Played       215 non-null    float64
#  6   Runs                 165 non-null    float64
#  7   Average              161 non-null    float64
#  8   Strike_Rate          163 non-null    float64
#  9   Wickets              140 non-null    float64
#  10  Bowling_average      135 non-null    float64
#  11  Economy              143 non-null    float64
#  12  Bowling_Strike_Rate  119 non-null    float64
#  13  Catches              27 non-null     float64
#  14  Run_outs             27 non-null     float64
# ...

# %%
bat=df.loc[df['Player_Type']=="Batter"]

# %%
bat
# Out:
#                 Player Name       Team Nationality Player_Type  Capped  \
# 0            Shikhar Dhawan     Punjab      Indian      Batter       1
# 1             Shreyas Iyer     Kolkata      Indian      Batter       1
# 2            Faf Du Plessis  Bangalore    Overseas      Batter       1
# 3            Manish Pandey     Lucknow      Indian      Batter       1
# 4           Shimron Hetmyer  Rajasthan    Overseas      Batter       1
# 5             Robin Uthappa    Chenai       Indian      Batter       1
# 6                 Jason Roy    Gujarat    Overseas      Batter       1
# 7          Devdutt Padikkal  Rajasthan      Indian      Batter       1
# 8               Priyam Garg  Hyderabad      Indian      Batter       1
# 9       Abhinav Sadarangani   Gujarat       Indian      Batter       0
# 10            Dewald Brevis     Mumbai    Overseas      Batter       0
# 11            Ashwin Hebbar      Delhi      Indian      Batter       0
# ...

# %%
batnew=bat[bat["Capped"]==1]

# %%
batnew
# Out:
#           Player Name       Team Nationality Player_Type  Capped  \
# 0      Shikhar Dhawan     Punjab      Indian      Batter       1
# 1       Shreyas Iyer     Kolkata      Indian      Batter       1
# 2      Faf Du Plessis  Bangalore    Overseas      Batter       1
# 3      Manish Pandey     Lucknow      Indian      Batter       1
# 4     Shimron Hetmyer  Rajasthan    Overseas      Batter       1
# 5       Robin Uthappa    Chenai       Indian      Batter       1
# 6           Jason Roy    Gujarat    Overseas      Batter       1
# 7    Devdutt Padikkal  Rajasthan      Indian      Batter       1
# 8         Priyam Garg  Hyderabad      Indian      Batter       1
# 12     Rahul Tripathi  Hyderabad      Indian      Batter       1
# 13      Aiden Markram  Hyderabad    Overseas      Batter       1
# 14    Ajinkya Rahane     Kolkata      Indian      Batter       1
# 15      Mandeep Singh      Delhi      Indian      Batter       1
# ...

# %%
capbat=batnew[['Player Name','Team','Nationality','Matches_Played','Runs','Average','Strike_Rate']]

# %%
capbat
# Out:
#           Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 0      Shikhar Dhawan     Punjab      Indian           192.0  5783.0    34.63
# 1       Shreyas Iyer     Kolkata      Indian            87.0  2375.0    31.67
# 2      Faf Du Plessis  Bangalore    Overseas           100.0  2935.0    34.94
# 3      Manish Pandey     Lucknow      Indian           154.0  3560.0    30.69
# 4     Shimron Hetmyer  Rajasthan    Overseas            31.0   517.0    25.85
# 5       Robin Uthappa    Chenai       Indian           193.0  4722.0    27.94
# 6           Jason Roy    Gujarat    Overseas            13.0   329.0    29.91
# 7    Devdutt Padikkal  Rajasthan      Indian            29.0   884.0    31.57
# 8         Priyam Garg  Hyderabad      Indian            19.0   205.0    14.64
# 12     Rahul Tripathi  Hyderabad      Indian            62.0  1385.0    26.13
# 13      Aiden Markram  Hyderabad    Overseas             6.0   146.0    29.30
# ...

# %%
df
# Out:
#          Player Name       Team Nationality Player_Type  Capped  \
# 0     Shikhar Dhawan     Punjab      Indian      Batter       1
# 1      Shreyas Iyer     Kolkata      Indian      Batter       1
# 2     Faf Du Plessis  Bangalore    Overseas      Batter       1
# 3     Manish Pandey     Lucknow      Indian      Batter       1
# 4    Shimron Hetmyer  Rajasthan    Overseas      Batter       1
# ..               ...        ...         ...         ...     ...
# 230     Ravi Bishnoi    Lucknow      Indian     Bowler        1
# 231  Ruturaj Gaikwad    Chennai      Indian      Batter       1
# 232    Sunil Narine     Kolkata    Overseas  Allrounder       1
# 233  Kieron Pollard      Mumbai    Overseas  Allrounder       1
# 234    Anrich Nortje      Delhi    Overseas     Bowler        1
#
#      Matches_Played    Runs  Average  Strike_Rate  Wickets  Bowling_average  \
# 0             192.0  5783.0    34.63       126.60      4.0            16.50
# ...

# %%
bowl=df.loc[df['Player_Type']=="Bowler "]

# %%
bowl
# Out:
#             Player Name       Team Nationality Player_Type  Capped  \
# 36       Kagiso Rabada      Punjab    Overseas     Bowler        1
# 37         Trent Boult   Rajasthan    Overseas     Bowler        1
# 38      Mohammad Shami     Gujarat      Indian     Bowler        1
# 39          T Natarajan  Hyderabad      Indian     Bowler        1
# 40       Deepak Chahar     Chennai      Indian     Bowler        1
# ..                  ...        ...         ...         ...     ...
# 214  Varun Chakravarthy    Kolkata      Indian     Bowler        1
# 215      Jasprit Bumrah     Mumbai      Indian     Bowler        1
# 227         Umran Malik  Hyderabad      Indian     Bowler        2
# 230        Ravi Bishnoi    Lucknow      Indian     Bowler        1
# 234       Anrich Nortje      Delhi    Overseas     Bowler        1
#
#      Matches_Played   Runs  Average  Strike_Rate  Wickets  Bowling_average  \
# 36             50.0  138.0    13.80       102.99     76.0            20.53
# ...

# %%
bowlnew=bowl[bowl["Capped"]==1]

# %%
capbowl=bowlnew[['Player Name','Team','Nationality','Matches_Played','Wickets','Bowling_average','Economy','Bowling_Strike_Rate']]

# %%
capbowl
# Out:
#              Player Name       Team Nationality  Matches_Played  Wickets  \
# 36        Kagiso Rabada      Punjab    Overseas            50.0     76.0
# 37          Trent Boult   Rajasthan    Overseas            62.0     76.0
# 38       Mohammad Shami     Gujarat      Indian            77.0     79.0
# 
# Out:
#          Player Name       Team Nationality Player_Type  Capped  \
# 105  Quinton De Kock    Lucknow    Overseas      Keeper       1
# 106    Ambati Rayudu    Chennai      Indian      Keeper       1
# 107     Ishan Kishan     Mumbai      Indian      Keeper       1
# 108   Jonny Bairstow     Punjab    Overseas      Keeper       1
# 109   Dinesh Karthik  Bangalore      Indian      Keeper       1
#
#      Matches_Played    Runs  Average  Strike_Rate  Wickets  Bowling_average  \
# 105            77.0  2256.0     31.3        130.9      NaN              NaN
# 106           175.0  3916.0     29.4        127.5      NaN              NaN
# 107            61.0  1452.0     28.5        136.3      NaN              NaN
# 108            28.0  1038.0     41.5        142.2      NaN              NaN
# 109           213.0  4046.0     25.8        129.7      NaN              NaN
#
#      Economy  Bowling_Strike_Rate  Catches  Run_outs  Stumps
# 105      NaN                  NaN     53.0       0.0    14.0
# ...

# %%
capkeep=keep[keep['Capped']==1]
capkeep.drop(['Capped'], axis=1)
# Out:
#            Player Name       Team Nationality Player_Type  Matches_Played  \
# 105    Quinton De Kock    Lucknow    Overseas      Keeper            77.0
# 106      Ambati Rayudu    Chennai      Indian      Keeper           175.0
# 107       Ishan Kishan     Mumbai      Indian      Keeper            61.0
# 108     Jonny Bairstow     Punjab    Overseas      Keeper            28.0
# 109     Dinesh Karthik  Bangalore      Indian      Keeper           213.0
# 110   Nicholas Pooran   Hyderabad    Overseas      Keeper            33.0
# 111          KS Bharat      Delhi      Indian      Keeper             8.0
# 112         Anuj Rawat  Bangalore      Indian      Keeper             1.0
# 113  Prabhsimran Singh     Punjab      Indian      Keeper             5.0
# 114   Sheldon Jackson     Kolkata    Overseas      Keeper             4.0
# 117      Sam Billings     Kolkata    Overseas      Keeper            22.0
# 118   Wridhhiman Saha     Gujarat      Indian      Keeper           133.0
# ...

# %%
capbat=capbat.fillna(0)

# %%
capalr=capalr.fillna(0)

# %%
capbowl=capbowl.fillna(0)

# %%
capkeep=capkeep.fillna(0)

# %%
print(capalr.isna().sum())
# Out:
# Player Name            0
# Team                   0
# Nationality            0
# Player_Type            0
# Capped                 0
# Matches_Played         0
# Runs                   0
# Average                0
# Strike_Rate            0
# Wickets                0
# Bowling_average        0
# Economy                0
# Bowling_Strike_Rate    0
# Catches                0
# Run_outs               0
# Stumps                 0
# dtype: int64

# %%
print(capbat.isna().sum())
# Out:
# Player Name       0
# Team              0
# Nationality       0
# Matches_Played    0
# Runs              0
# Average           0
# Strike_Rate       0
# dtype: int64

# %%
print(capkeep.isna().sum())
# Out:
# Player Name            0
# Team                   0
# Nationality            0
# Player_Type            0
# Capped                 0
# Matches_Played         0
# Runs                   0
# Average                0
# Strike_Rate            0
# Wickets                0
# Bowling_average        0
# Economy                0
# Bowling_Strike_Rate    0
# Catches                0
# Run_outs               0
# Stumps                 0
# dtype: int64

# %%
print(capbowl.isna().sum())
# Out:
# Player Name            0
# Team                   0
# Nationality            0
# Matches_Played         0
# Wickets                0
# Bowling_average        0
# Economy                0
# Bowling_Strike_Rate    0
# dtype: int64

# %%
tb=capbat[capbat["Average"]>32]

# %% [markdown]
# tb

# %%
tb
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 0     Shikhar Dhawan     Punjab      Indian           192.0  5783.0    34.63
# 2     Faf Du Plessis  Bangalore    Overseas           100.0  2935.0    34.94
# 19     David Warner       Delhi    Overseas           150.0  5449.0    41.60
# 26     David Miller     Gujarat    Overseas            89.0  1974.0    32.90
# 207  Kane Williamson  Hyderabad    Overseas            63.0  1885.0    40.11
# 208      Virat Kohli  Bangalore      Indian           207.0  6283.0    37.40
# 212        KL Rahul     Lucknow      Indian            94.0  3273.0    47.43
# 231  Ruturaj Gaikwad    Chennai      Indian            22.0   839.0    46.61
#
#      Strike_Rate
# 0         126.60
# 2         131.09
# 19        139.97
# 26        136.51
# 207       131.27
# 208       129.95
# 212       136.38
# 231       132.13

# %%
tbavg=tb.sort_values('Average',ascending=False)

# %%
tbsr=tb.sort_values('Strike_Rate',ascending=False)
tbr=tb.sort_values('Runs',ascending=False)

# %%
tbm=tb.sort_values('Matches_Played',ascending=False)

# %%
tbavg
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 212        KL Rahul     Lucknow      Indian            94.0  3273.0    47.43
# 231  Ruturaj Gaikwad    Chennai      Indian            22.0   839.0    46.61
# 19     David Warner       Delhi    Overseas           150.0  5449.0    41.60
# 207  Kane Williamson  Hyderabad    Overseas            63.0  1885.0    40.11
# 208      Virat Kohli  Bangalore      Indian           207.0  6283.0    37.40
# 2     Faf Du Plessis  Bangalore    Overseas           100.0  2935.0    34.94
# 0     Shikhar Dhawan     Punjab      Indian           192.0  5783.0    34.63
# 26     David Miller     Gujarat    Overseas            89.0  1974.0    32.90
#
#      Strike_Rate
# 212       136.38
# 231       132.13
# 19        139.97
# 207       131.27
# 208       129.95
# 2         131.09
# 0         126.60
# 26        136.51

# %%
tbsr
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 19     David Warner       Delhi    Overseas           150.0  5449.0    41.60
# 26     David Miller     Gujarat    Overseas            89.0  1974.0    32.90
# 212        KL Rahul     Lucknow      Indian            94.0  3273.0    47.43
# 231  Ruturaj Gaikwad    Chennai      Indian            22.0   839.0    46.61
# 207  Kane Williamson  Hyderabad    Overseas            63.0  1885.0    40.11
# 2     Faf Du Plessis  Bangalore    Overseas           100.0  2935.0    34.94
# 208      Virat Kohli  Bangalore      Indian           207.0  6283.0    37.40
# 0     Shikhar Dhawan     Punjab      Indian           192.0  5783.0    34.63
#
#      Strike_Rate
# 19        139.97
# 26        136.51
# 212       136.38
# 231       132.13
# 207       131.27
# 2         131.09
# 208       129.95
# 0         126.60

# %%
tbr
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 208      Virat Kohli  Bangalore      Indian           207.0  6283.0    37.40
# 0     Shikhar Dhawan     Punjab      Indian           192.0  5783.0    34.63
# 19     David Warner       Delhi    Overseas           150.0  5449.0    41.60
# 212        KL Rahul     Lucknow      Indian            94.0  3273.0    47.43
# 2     Faf Du Plessis  Bangalore    Overseas           100.0  2935.0    34.94
# 26     David Miller     Gujarat    Overseas            89.0  1974.0    32.90
# 207  Kane Williamson  Hyderabad    Overseas            63.0  1885.0    40.11
# 231  Ruturaj Gaikwad    Chennai      Indian            22.0   839.0    46.61
#
#      Strike_Rate
# 208       129.95
# 0         126.60
# 19        139.97
# 212       136.38
# 2         131.09
# 26        136.51
# 207       131.27
# 231       132.13

# %%
tbm
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 208      Virat Kohli  Bangalore      Indian           207.0  6283.0    37.40
# 0     Shikhar Dhawan     Punjab      Indian           192.0  5783.0    34.63
# 19     David Warner       Delhi    Overseas           150.0  5449.0    41.60
# 2     Faf Du Plessis  Bangalore    Overseas           100.0  2935.0    34.94
# 212        KL Rahul     Lucknow      Indian            94.0  3273.0    47.43
# 26     David Miller     Gujarat    Overseas            89.0  1974.0    32.90
# 207  Kane Williamson  Hyderabad    Overseas            63.0  1885.0    40.11
# 231  Ruturaj Gaikwad    Chennai      Indian            22.0   839.0    46.61
#
#      Strike_Rate
# 208       129.95
# 0         126.60
# 19        139.97
# 2         131.09
# 212       136.38
# 26        136.51
# 207       131.27
# 231       132.13

# %% [markdown]
# now according to the given dataset we find that the top 3 players are
# 1.david warner
# 2.k l rahul
# 3.virat kohli

# %%
tal=capalr[alr["Strike_Rate"]>140]
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.

# %%
tala=tal.sort_values("Average",ascending=False)
talm=tal.sort_values("Matches_Played",ascending=False)
talsr=tal.sort_values("Strike_Rate",ascending=False)
talr=tal.sort_values("Runs",ascending=False)
talw=tal.sort_values("Wickets",ascending=False)
tale=tal.sort_values("Economy")
talbsr=tal.sort_values("Bowling_Strike_Rate")
talba=tal.sort_values("Bowling_average")

# %%
tala
# Out:
#          Player Name       Team Nationality Player_Type  Capped  \
# 233  Kieron Pollard      Mumbai    Overseas  Allrounder       1
# 204    Andre Russell    Kolkata    Overseas  Allrounder       1
# 211    Hardik Pandya    Gujarat      Indian  Allrounder       1
# 218     Glen Maxwell  Bangalore    Overseas  Allrounder       1
# 223        Moeen Ali    Chennai    Overseas  Allrounder       1
# 128     Pat Cummins     Kolkata    Overseas  Allrounder       1
# 232    Sunil Narine     Kolkata    Overseas  Allrounder       1
# 165     Jofra Archer     Mumbai    Overseas  Allrounder       1
# 195   Mohammad Nabi     Kolkata    Overseas  Allrounder       1
# 154       K Gowtham     Lucknow      Indian  Allrounder       1
# 202       Aman Khan     Kolkata      Indian  Allrounder       1
#
#      Matches_Played    Runs  Average  Strike_Rate  Wickets  Bowling_average  \
# 233           178.0  3268.0    29.98       149.77     65.0            31.62
# ...

# %%
talba
# Out:
#          Player Name       Team Nationality Player_Type  Capped  \
# 202       Aman Khan     Kolkata      Indian  Allrounder       1
# 165     Jofra Archer     Mumbai    Overseas  Allrounder       1
# 232    Sunil Narine     Kolkata    Overseas  Allrounder       1
# 204    Andre Russell    Kolkata    Overseas  Allrounder       1
# 223        Moeen Ali    Chennai    Overseas  Allrounder       1
# 128     Pat Cummins     Kolkata    Overseas  Allrounder       1
# 211    Hardik Pandya    Gujarat      Indian  Allrounder       1
# 195   Mohammad Nabi     Kolkata    Overseas  Allrounder       1
# 233  Kieron Pollard      Mumbai    Overseas  Allrounder       1
# 218     Glen Maxwell  Bangalore    Overseas  Allrounder       1
# 154       K Gowtham     Lucknow      Indian  Allrounder       1
#
#      Matches_Played    Runs  Average  Strike_Rate  Wickets  Bowling_average  \
# 202             5.0    40.0    13.30       148.10      0.0             0.00
# ...

# %%
talbsr
# Out:
#          Player Name       Team Nationality Player_Type  Capped  \
# 202       Aman Khan     Kolkata      Indian  Allrounder       1
# 204    Andre Russell    Kolkata    Overseas  Allrounder       1
# 165     Jofra Archer     Mumbai    Overseas  Allrounder       1
# 211    Hardik Pandya    Gujarat      Indian  Allrounder       1
# 233  Kieron Pollard      Mumbai    Overseas  Allrounder       1
# 232    Sunil Narine     Kolkata    Overseas  Allrounder       1
# 128     Pat Cummins     Kolkata    Overseas  Allrounder       1
# 223        Moeen Ali    Chennai    Overseas  Allrounder       1
# 195   Mohammad Nabi     Kolkata    Overseas  Allrounder       1
# 218     Glen Maxwell  Bangalore    Overseas  Allrounder       1
# 154       K Gowtham     Lucknow      Indian  Allrounder       1
#
#      Matches_Played    Runs  Average  Strike_Rate  Wickets  Bowling_average  \
# 202             5.0    40.0    13.30       148.10      0.0             0.00
# ...

# %%
tale
# Out:
#          Player Name       Team Nationality Player_Type  Capped  \
# 232    Sunil Narine     Kolkata    Overseas  Allrounder       1
# 223        Moeen Ali    Chennai    Overseas  Allrounder       1
# 202       Aman Khan     Kolkata      Indian  Allrounder       1
# 165     Jofra Archer     Mumbai    Overseas  Allrounder       1
# 195   Mohammad Nabi     Kolkata    Overseas  Allrounder       1
# 128     Pat Cummins     Kolkata    Overseas  Allrounder       1
# 154       K Gowtham     Lucknow      Indian  Allrounder       1
# 218     Glen Maxwell  Bangalore    Overseas  Allrounder       1
# 233  Kieron Pollard      Mumbai    Overseas  Allrounder       1
# 204    Andre Russell    Kolkata    Overseas  Allrounder       1
# 211    Hardik Pandya    Gujarat      Indian  Allrounder       1
#
#      Matches_Played    Runs  Average  Strike_Rate  Wickets  Bowling_average  \
# 232           134.0   954.0    15.64       161.69    143.0            24.53
# ...

# %%
talm
# Out:
#          Player Name       Team Nationality Player_Type  Capped  \
# 233  Kieron Pollard      Mumbai    Overseas  Allrounder       1
# 232    Sunil Narine     Kolkata    Overseas  Allrounder       1
# 218     Glen Maxwell  Bangalore    Overseas  Allrounder       1
# 211    Hardik Pandya    Gujarat      Indian  Allrounder       1
# 204    Andre Russell    Kolkata    Overseas  Allrounder       1
# 128     Pat Cummins     Kolkata    Overseas  Allrounder       1
# 165     Jofra Archer     Mumbai    Overseas  Allrounder       1
# 223        Moeen Ali    Chennai    Overseas  Allrounder       1
# 154       K Gowtham     Lucknow      Indian  Allrounder       1
# 195   Mohammad Nabi     Kolkata    Overseas  Allrounder       1
# 202       Aman Khan     Kolkata      Indian  Allrounder       1
#
#      Matches_Played    Runs  Average  Strike_Rate  Wickets  Bowling_average  \
# 233           178.0  3268.0    29.98       149.77     65.0            31.62
# ...

# %%
talsr
# Out:
#          Player Name       Team Nationality Player_Type  Capped  \
# 204    Andre Russell    Kolkata    Overseas  Allrounder       1
# 154       K Gowtham     Lucknow      Indian  Allrounder       1
# 232    Sunil Narine     Kolkata    Overseas  Allrounder       1
# 165     Jofra Archer     Mumbai    Overseas  Allrounder       1
# 211    Hardik Pandya    Gujarat      Indian  Allrounder       1
# 218     Glen Maxwell  Bangalore    Overseas  Allrounder       1
# 195   Mohammad Nabi     Kolkata    Overseas  Allrounder       1
# 233  Kieron Pollard      Mumbai    Overseas  Allrounder       1
# 202       Aman Khan     Kolkata      Indian  Allrounder       1
# 223        Moeen Ali    Chennai    Overseas  Allrounder       1
# 128     Pat Cummins     Kolkata    Overseas  Allrounder       1
#
#      Matches_Played    Runs  Average  Strike_Rate  Wickets  Bowling_average  \
# 204            84.0  1700.0    29.31       178.57     72.0            26.40
# ...

# %% [markdown]
# So from the above tables we find that the top bowlers available are:
# 1.andre russel
# 2.sunil narine
# 3.hardik pandya
# 4.jofra archer

# %%
capkeep=capkeep.drop(['Capped'], axis=1)

# %%
capkeep.head()
# Out:
#          Player Name       Team Nationality Player_Type  Matches_Played  \
# 105  Quinton De Kock    Lucknow    Overseas      Keeper            77.0
# 106    Ambati Rayudu    Chennai      Indian      Keeper           175.0
# 107     Ishan Kishan     Mumbai      Indian      Keeper            61.0
# 108   Jonny Bairstow     Punjab    Overseas      Keeper            28.0
# 109   Dinesh Karthik  Bangalore      Indian      Keeper           213.0
#
#        Runs  Average  Strike_Rate  Wickets  Bowling_average  Economy  \
# 105  2256.0     31.3        130.9      0.0              0.0      0.0
# 106  3916.0     29.4        127.5      0.0              0.0      0.0
# 107  1452.0     28.5        136.3      0.0              0.0      0.0
# 108  1038.0     41.5        142.2      0.0              0.0      0.0
# 109  4046.0     25.8        129.7      0.0              0.0      0.0
#
#      Bowling_Strike_Rate  Catches  Run_outs  Stumps
# 105                  0.0     53.0       0.0    14.0
# ...

# %%
tk=capkeep[(capkeep["Average"]>=25.0)]

# %%
tkc=tk.sort_values('Catches',ascending=False)

# %%
tkw=tk.sort_values('Wickets',ascending=False)
tksr=tk.sort_values('Strike_Rate',ascending=False)
tkm=tk.sort_values('Matches_Played',ascending=False)

# %%
tkso=tk.sort_values('Stumps',ascending=False)
tkro=tk.sort_values('Run_outs',ascending=False)
tka=tk.sort_values('Average',ascending=False)

# %%
tkw
# Out:
#          Player Name       Team Nationality Player_Type  Matches_Played  \
# 105  Quinton De Kock    Lucknow    Overseas      Keeper            77.0
# 106    Ambati Rayudu    Chennai      Indian      Keeper           175.0
# 107     Ishan Kishan     Mumbai      Indian      Keeper            61.0
# 108   Jonny Bairstow     Punjab    Overseas      Keeper            28.0
# 109   Dinesh Karthik  Bangalore      Indian      Keeper           213.0
# 111        KS Bharat      Delhi      Indian      Keeper             8.0
# 206    Rishabh Pant       Delhi      Indian      Keeper            84.0
# 209     Sanju Samson  Rajasthan      Indian      Keeper           121.0
# 213         MS Dhoni    Chennai      Indian      Keeper           220.0
# 219       Jos Butler  Rajasthan    Overseas      Keeper            65.0
#
#        Runs  Average  Strike_Rate  Wickets  Bowling_average  Economy  \
#
0
#
#        Runs  Average  Strike_Rate  Wickets  Bowling_average  Economy  \
# 108  1038.0    41.50       142.20      0.0              0.0      0.0
# ...

# %%
tkro
# Out:
#          Player Name       Team Nationality Player_Type  Matches_Played  \
# 213         MS Dhoni    Chennai      Indian      Keeper           220.0
# 109   Dinesh Karthik  Bangalore      Indian      Keeper           213.0
# 106    Ambati Rayudu    Chennai      Indian      Keeper           175.0
# 209     Sanju Samson  Rajasthan      Indian      Keeper           121.0
# 206    Rishabh Pant       Delhi      Indian      Keeper            84.0
# 219       Jos Butler  Rajasthan    Overseas      Keeper            65.0
# 107     Ishan Kishan     Mumbai      Indian      Keeper            61.0
# 108   Jonny Bairstow     Punjab    Overseas      Keeper            28.0
# 105  Quinton De Kock    Lucknow    Overseas      Keeper            77.0
# 111        KS Bharat      Delhi      Indian      Keeper             8.0
#
#        Runs  Average  Strike_Rate  Wickets  Bowling_average  Economy  \
# 213  4746.0    39.50       135.80      0.0              0.0      0.0
# ...

# %%
tkc
# Out:
#          Player Name       Team Nationality Player_Type  Matches_Played  \
# 213         MS Dhoni    Chennai      Indian      Keeper           220.0
# 109   Dinesh Karthik  Bangalore      Indian      Keeper           213.0
# 209     Sanju Samson  Rajasthan      Indian      Keeper           121.0
# 106    Ambati Rayudu    Chennai      Indian      Keeper           175.0
# 206    Rishabh Pant       Delhi      Indian      Keeper            84.0
# 105  Quinton De Kock    Lucknow    Overseas      Keeper            77.0
# 219       Jos Butler  Rajasthan    Overseas      Keeper            65.0
# 107     Ishan Kishan     Mumbai      Indian      Keeper            61.0
# 108   Jonny Bairstow     Punjab    Overseas      Keeper            28.0
# 111        KS Bharat      Delhi      Indian      Keeper             8.0
#
#        Runs  Average  Strike_Rate  Wickets  Bowling_average  Economy  \
# 213  4746.0    39.50       135.80      0.0              0.0      0.0
# ...

# %% [markdown]
# the top 3 wicket keepers as per data are:
# 1.ms dhoni
# 2.dinesh kartik
# 3.risabh pant

# %%
tbo=capbowl[capbowl['Bowling_average']<=24.0]

# %%
tba=tbo.sort_values('Bowling_average')

# %%
tbor=tbo.sort_values('Bowling_Strike_Rate')
tbow=tbo.sort_values('Wickets',ascending=False)
tboe=tbo.sort_values('Economy')
tbom=tba=tbo.sort_values('Matches_Played')

# %%
tbor
# Out:
#              Player Name       Team Nationality  Matches_Played  Wickets  \
# 83            Rasikh Dar    Kolkata      Indian             1.0      1.0
# 87           Sean Abbott  Hyderabad    Overseas             2.0      0.0
# 101         Kuldip Yadav  Rajasthan      Indian             1.0      0.0
# 88        Alzarri Joseph    Gujarat    Overseas             3.0      6.0
# 93          Lungi Ngidi      Delhi     Overseas            14.0     25.0
# 36        Kagiso Rabada      Punjab    Overseas            50.0     76.0
# 210      Arshdeep Singh      Punjab      Indian            23.0     30.0
# 234        Anrich Nortje      Delhi    Overseas            24.0     34.0
# 103  Nathan Coulter-Nile  Rajasthan    Overseas            38.0     48.0
# 50     Yuzvendra Chahal   Rajasthan      Indian           114.0    139.0
# 215       Jasprit Bumrah     Mumbai      Indian           106.0    130.0
# 214   Varun Chakravarthy    Kolkata      Indian            31.0     36.0
#
# ...

# %%
tbom
# Out:
#              Player Name       Team Nationality  Matches_Played  Wickets  \
# 83            Rasikh Dar    Kolkata      Indian             1.0      1.0
# 101         Kuldip Yadav  Rajasthan      Indian             1.0      0.0
# 87           Sean Abbott  Hyderabad    Overseas             2.0      0.0
# 88        Alzarri Joseph    Gujarat    Overseas             3.0      6.0
# 93          Lungi Ngidi      Delhi     Overseas            14.0     25.0
# 210      Arshdeep Singh      Punjab      Indian            23.0     30.0
# 234        Anrich Nortje      Delhi    Overseas            24.0     34.0
# 214   Varun Chakravarthy    Kolkata      Indian            31.0     36.0
# 103  Nathan Coulter-Nile  Rajasthan    Overseas            38.0     48.0
# 36        Kagiso Rabada      Punjab    Overseas            50.0     76.0
# 215       Jasprit Bumrah     Mumbai      Indian           106.0    130.0
# 50     Yuzvendra Chahal   Rajasthan      Indian           114.0    139.0
#
# ...

# %%
tbow
# Out:
#              Player Name       Team Nationality  Matches_Played  Wickets  \
# 50     Yuzvendra Chahal   Rajasthan      Indian           114.0    139.0
# 215       Jasprit Bumrah     Mumbai      Indian           106.0    130.0
# 36        Kagiso Rabada      Punjab    Overseas            50.0     76.0
# 103  Nathan Coulter-Nile  Rajasthan    Overseas            38.0     48.0
# 214   Varun Chakravarthy    Kolkata      Indian            31.0     36.0
# 234        Anrich Nortje      Delhi    Overseas            24.0     34.0
# 210      Arshdeep Singh      Punjab      Indian            23.0     30.0
# 93          Lungi Ngidi      Delhi     Overseas            14.0     25.0
# 88        Alzarri Joseph    Gujarat    Overseas             3.0      6.0
# 83            Rasikh Dar    Kolkata      Indian             1.0      1.0
# 87           Sean Abbott  Hyderabad    Overseas             2.0      0.0
# 101         Kuldip Yadav  Rajasthan      Indian             1.0      0.0
#
# ...

# %%
tboe
# Out:
#              Player Name       Team Nationality  Matches_Played  Wickets  \
# 214   Varun Chakravarthy    Kolkata      Indian            31.0     36.0
# 215       Jasprit Bumrah     Mumbai      Indian           106.0    130.0
# 103  Nathan Coulter-Nile  Rajasthan    Overseas            38.0     48.0
# 50     Yuzvendra Chahal   Rajasthan      Indian           114.0    139.0
# 234        Anrich Nortje      Delhi    Overseas            24.0     34.0
# 101         Kuldip Yadav  Rajasthan      Indian             1.0      0.0
# 36        Kagiso Rabada      Punjab    Overseas            50.0     76.0
# 93          Lungi Ngidi      Delhi     Overseas            14.0     25.0
# 210      Arshdeep Singh      Punjab      Indian            23.0     30.0
# 88        Alzarri Joseph    Gujarat    Overseas             3.0      6.0
# 83            Rasikh Dar    Kolkata      Indian             1.0      1.0
# 87           Sean Abbott  Hyderabad    Overseas             2.0      0.0
#
# ...

# %% [markdown]
# the top 4 bowlers are:
# 1.rabada
# 2.bumrah
# 3.chahal
# 4.coulter nile

# %% [markdown]
# #visualization of batters data

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='Player Name', y='Strike_Rate',data=tb)

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='Player Name', y='Runs',data=tb)

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='Player Name', y='Average',data=tb)

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='Player Name', y='Matches_Played',data=tb)

# %% [markdown]
# #visualization of bowlers data

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='Player Name',y='Bowling_average',data=tbo)

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='Player Name',y='Economy',data=tbo)

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='Player Name',y='Bowling_Strike_Rate',data=tbo)

# %% [markdown]
# #visualization of all rounders

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='Player Name',y='Strike_Rate',data=tal)

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='Player Name',y='Average',data=tal)

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='Player Name',y='Runs',data=tal)

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='Player Name',y='Economy',data=tal)

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='Player Name',y='Wickets',data=tal)

# %% [markdown]
# #visualization in wicket keepers

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='Player Name',y='Average',data=tk)

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='Player Name',y='Stumps',data=tk)

# %% [markdown]
# #best 11 team formations:
# a.3 batters
# b.4 bowlers
# c.3 all rounders
# d.1 wicket keeper

# %% [markdown]
# #visualization of stats of top batsmen in this ipl

# %%
tb.reset_index(drop=True)
matplay=[tb.iloc[6]['Matches_Played'],tb.iloc[2]['Matches_Played'],tb.iloc[5]['Matches_Played']]
matrun=[tb.iloc[6]['Runs'],tb.iloc[2]['Runs'],tb.iloc[5]['Runs']]
matav=[tb.iloc[6]['Average'],tb.iloc[2]['Average'],tb.iloc[5]['Average']]
matsr=[tb.iloc[6]['Strike_Rate'],tb.iloc[2]['Strike_Rate'],tb.iloc[5]['Strike_Rate']]
labels=['KL RAHUL','DAVID WARNER','VIRAT KOHLI']

fig,axes=plt.subplots(2,2,figsize=(10,10))
axes[0][0].set_title("Matches played")
axes[0][1].set_title("Runs in ipl")
axes[1][0].set_title("Strike rate")
axes[1][1].set_title("Average")

sns.barplot(x=labels,y=matplay,ax=axes[0][0])
sns.barplot(x=labels,y=matrun,ax=axes[0][1])
sns.barplot(x=labels,y=matav,ax=axes[1][0])
sns.barplot(x=labels,y=matsr,ax=axes[1][1])

# %% [markdown]
# #visualization of top allrounder stats

# %%
tal.reset_index(drop=True)
matplay=[tal.iloc[5]['Matches_Played'],tal.iloc[9]['Matches_Played'],tal.iloc[6]['Matches_Played']]
matrun=[tal.iloc[5]['Runs'],tal.iloc[9]['Runs'],tal.iloc[6]['Runs']]
matav=[tal.iloc[5]['Average'],tal.iloc[9]['Average'],tal.iloc[6]['Average']]
matsr=[tal.iloc[5]['Strike_Rate'],tal.iloc[9]['Strike_Rate'],tal.iloc[6]['Strike_Rate']]
matbsr=[tal.iloc[5]['Bowling_Strike_Rate'],tal.iloc[9]['Bowling_Strike_Rate'],tal.iloc[6]['Bowling_Strike_Rate']]
matbav=[tal.iloc[5]['Bowling_average'],tal.iloc[9]['Bowling_average'],tal.iloc[6]['Bowling_average']]
matw=[tal.iloc[5]['Wickets'],tal.iloc[9]['Wickets'],tal.iloc[6]['Wickets']]
mate=[tal.iloc[5]['Economy'],tal.iloc[9]['Economy'],tal.iloc[6]['Economy']]
labels=['Andre russel','Sunil narine','Hardik pandya']

fig,axes=plt.subplots(4,2,figsize=(20,20))
axes[0][0].set_title("Matches played")
axes[0][1].set_title("Runs in ipl")
axes[1][0].set_title("Average")
axes[1][1].set_title("Strike rate")
axes[2][0].set_title("Bowling Strike")
axes[2][1].set_title("Bowling_average")
axes[3][0].set_titlem("Wickets")

sns.barplot(x=labels,y=matplay,ax=axes[0][0])
sns.barplot(x=labels,y=matrun,ax=axes[0][1])
sns.barplot(x=labels,y=matav,ax=axes[1][0])
sns.barplot(x=labels,y=matsr,ax=axes[1][1])
sns.barplot(x=labels,y=matbsr,ax=axes[2][0])
sns.barplot(x=labels,y=matbav,ax=axes[2][1])
sns.barplot(x=labels,y=matw,ax=axes[3][0])
sns.barplot(x=labels,y=mate,ax=axes[3][1])

# %% [markdown]
# #visualization of top bowler stats

# %%
tbo.reset_index(drop=True)
matplay=[tbo.iloc[10]['Matches_Played'],tbo.iloc[0]['Matches_Played'],tbo.iloc[7]['Matches_Played'],tbo.iloc[1]['Matches_Played']]
matbsr=[tbo.iloc[10]['Bowling_Strike_Rate'],tbo.iloc[0]['Bowling_Strike_Rate'],tbo.iloc[7]['Bowling_Strike_Rate'],tbo.iloc[1]['Bowling_Strike_Rate']]
matbav=[tbo.iloc[10]['Bowling_average'],tbo.iloc[0]['Bowling_average'],tbo.iloc[7]['Bowling_average'],tbo.iloc[1]['Bowling_average']]
matw=[tbo.iloc[10]['Wickets'],tbo.iloc[0]['Wickets'],tbo.iloc[7]['Wickets'],tbo.iloc[1]['Wickets']]
mate=[tbo.iloc[10]['Economy'],tbo.iloc[0]['Economy'],tbo.iloc[7]['Economy'],tbo.iloc[1]['Economy']]
labels=['bumrah','Rabada','coulter Nile','chahal']

fig,axes=plt.subplots(3,2,figsize=(20,20))
axes[0][0].set_title("Matches played")
axes[0][1].set_title("Bowling Strike")
axes[1][0].set_title("Bowling_average")
axes[1][1].set_title("Wickets")
axes[2][0].set_title("economony")

sns.barplot(x=labels,y=matplay,ax=axes[0][0])
sns.barplot(x=labels,y=matbsr,ax=axes[0][1])
sns.barplot(x=labels,y=matbav,ax=axes[1][0])
sns.barplot(x=labels,y=matw,ax=axes[1][1])
sns.barplot(x=labels,y=mate,ax=axes[2][0])

# %% [markdown]
# #visualization of wicket keeper

# %%
matplay=[tk.iloc[8]['Matches_Played'],tk.iloc[8]['Runs']]
mat=[tk.iloc[8]['Average'],tk.iloc[8]['Strike_Rate']]
matk=[tk.iloc[8]['Catches'],tk.iloc[8]['Stumps'],tk.iloc[8]['Run_outs']]

label1=['Matches_Played','Runs']
label2=['Average','Strike_Rate']
label3=['Catches','Stumps','Run_outs',]
         
fig,axes=plt.subplots(1,3,figsize=(20,10))
axes[0].set_title("Matches played and runs scored")
axes[1].set_title("average and strike rate")
axes[2].set_title("Catches,stumps,run outs")
sns.barplot(x=label1,y=matplay,ax=axes[0])
sns.barplot(x=label2,y=mat,ax=axes[1])
sns.barplot(x=label3,y=matk,ax=axes[2])

# %%
b1=tb.loc[tb['Player Name']=='KL Rahul ']
b2=tb.loc[tb['Player Name']=='David Warner ']
b3=tb.loc[tb['Player Name']=='Virat Kohli']

bo1=tbo.loc[tbo['Player Name']=='Yuzvendra Chahal ']
bo2=tbo.loc[tbo['Player Name']=='Jasprit Bumrah']
bo3=tbo.loc[tbo['Player Name']=='Nathan Coulter-Nile']
bo4=tbo.loc[tbo['Player Name']=='Kagiso Rabada ']

a1=tal.loc[tal['Player Name']=='Andre Russell']
a2=tal.loc[tal['Player Name']=='Sunil Narine ']
a3=tal.loc[tal['Player Name']=='Hardik Pandya']

k=tk.loc[tk['Player Name']=='MS Dhoni']

# %%
final=[b1,b2,b3,bo1,bo2,bo3,bo4,a1,a2,a3,k]
finteam=pd.concat(final)
finteam.drop(labels=['Matches_Played','Runs','Average','Strike_Rate','Catches','Stumps','Run_outs','Bowling_average','Bowling_Strike_Rate','Economy','Wickets','Player_Type','Capped'],axis=1)
# Out:
#              Player Name       Team Nationality
# 212            KL Rahul     Lucknow      Indian
# 19         David Warner       Delhi    Overseas
# 208          Virat Kohli  Bangalore      Indian
# 50     Yuzvendra Chahal   Rajasthan      Indian
# 215       Jasprit Bumrah     Mumbai      Indian
# 103  Nathan Coulter-Nile  Rajasthan    Overseas
# 36        Kagiso Rabada      Punjab    Overseas
# 204        Andre Russell    Kolkata    Overseas
# 232        Sunil Narine     Kolkata    Overseas
# 211        Hardik Pandya    Gujarat      Indian
# 213             MS Dhoni    Chennai      Indian
